# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function
from __future__ import unicode_literals

import math
import os
import sys
import warnings
import argparse
import numpy as np
import yaml
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

from multiprocessing import Lock
from multiprocessing.pool import ThreadPool
from multiprocessing import Pool, cpu_count

import time
import threading
import random 
from sklearn import mixture
from sklearn.utils import shuffle
from skimage import measure

from glob import glob
from tqdm import tqdm
import math

sys.path.append("/home/shiyi/gpu/gpu/")
sys.path.append("/home/shiyi/colposcopy/colposcopy/util")
img_dir_origin = "/data/colposcopy/colposcopy/"
img_dir_modified = "/data/colposcopy/colposcopy_1/"
target_dir = ''
from gpu_allocation import set_gpu

# %%
import csv
def bbox_file_reader(file_name):
    csv_path = os.path.join(img_dir_origin,file_name)
    f = open(csv_path)
    f_csv = csv.reader(f)
    pic_dict = {}
    for row, in f_csv:
        type_cur = row.split('\\')[0]
        name_cur = row.split('\\')[1].split()[0]
        num_cur =  int(row.split()[1])
        boxes = row.split()[2:6]
        path = os.path.join(img_dir_origin,'train','_'.join(file_name.split('_')[:2]),name_cur)
        #print([path,boxes])
        label = 0
        if os.path.exists(path):
            label = 1
            pic_dict[path] = boxes
            #print([path,boxes])
    return pic_dict
    
bbox_1 = bbox_file_reader("Type_1_bbox.tsv")
bbox_2 = bbox_file_reader("Type_2_bbox.tsv")
bbox_3 = bbox_file_reader("Type_3_bbox.tsv")

dictMerged = dict( bbox_1, **bbox_2 )
img_paths = dict( dictMerged, **bbox_3 )
print (len(img_paths))
print (bbox_1.items()[0])
# Out:
# 1466
# (u'/data/colposcopy/colposcopy/train/Type_1/1199.jpg', ['744', '1304', '230', '266'])

# %%
def remove_sr(img): 
    r_c = img[:,:,2]
    g_c = img[:,:,1]
    b_c = img[:,:,0]
    _,r_thres = cv2.threshold(r_c, 190, 255, cv2.THRESH_BINARY)
    _,g_thres = cv2.threshold(g_c, 180, 255, cv2.THRESH_BINARY)
    _,b_thres = cv2.threshold(b_c, 210, 255, cv2.THRESH_BINARY)
    mixed = r_thres & b_thres & g_thres 
    kernel_dilate = np.ones((18, 18), np.uint8)
    mask = cv2.dilate(mixed,kernel_dilate)
    dst = cv2.inpaint(img,mixed,14,cv2.INPAINT_TELEA)
    return dst

def cvt(img):
    return cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

def plot(img,coords):
    colors = plt.cm.hsv(np.linspace(0, 1, 100)).tolist()
    color = colors[random.randint(0,99)]
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))  # plot the image for matplotlib
    currentAxis = plt.gca()
    currentAxis.add_patch(plt.Rectangle(*coords, fill=False, edgecolor=color, linewidth=1))
    #currentAxis.text(pt[0], pt[1], label, bbox={'facecolor':color, 'alpha':0.5})
    
def crop_img(file_name,bboxes): 
    img = cv2.imread(file_name)
    label = file_name.split('/')[-2]
    plt.figure(figsize=(10,10))
    box = bboxes
    pt = [int(i) for i in box]
    coords = (pt[0], pt[1]), pt[2],pt[3]
    pt_x_min = pt[0]
    pt_x_max = pt[0]+pt[2]-1
    pt_y_min = pt[1]dic
    pt_y_max = pt[1]+pt[3]-1
    return img[pt_y_min:pt_y_max,pt_x_min:pt_x_max],coords

img_name,bboxes = bbox_1[87]
img = cv2.imread(img_name)
img_cropped,coords = crop_img(img_name,bboxes)
o_shape = img.shape
shape = img_croped.shape
print(o_shape,shape)
# Out:
# (4128, 3096, 3) (1051, 714, 3)

# %%
from multiprocessing import Lock
from multiprocessing.dummy import Pool as ThreadPool 
import time
import threading
from tqdm import tqdm
import os
import numpy as np

num_thread = 30
num_images = len(img_paths)
print (num_images)
pool = ThreadPool(num_thread)

def preprocess_cervical_1(item):
    global progress,lock
    #print("Thread {}, image {}|{}, name: {}".format(thread_id, index-index_slice[0], len(index_slice) ,img_paths[index]))
    name,box = item
    img_name_target = os.path.join(img_dir_modified + '/'.join(name.split('/')[4:]))
    print (name,box)
    try:
        img = cv2.imread(name)
        if img is not None:
            img_crop,_ = crop_img(img,box)
            dst = remove_sr(img_crop)
            cv2.imwrite(img_name_target,dst)
    except cv2.error:
        print ("skipped,continue")

print ('Parent process %s.' % os.getpid())
start_time = time.time()
a = pool.map(preprocess_cervical_1, img_paths)
pool.close()
pool.join()
end_time = time.time()

print ("done,it takes:",end_time-start_time)
# Out:
# 1466
# Parent process 17677.
# /data/colposcopy/colposcopy/train/Type_1/0.jpg ['882', '961', '1042', '1106']
# /data/colposcopy/colposcopy/train/Type_1/1056.jpg ['828', '884', '1194', '1118']
# /data/colposcopy/colposcopy/train/Type_1/1134.jpg/data/colposcopy/colposcopy/train/Type_1/1204.jpg ['698', '691', '1998', '2659']
# /data/colposcopy/colposcopy/train/Type_1/1285.jpg ['714', '1032', '762', '671']
#  /data/colposcopy/colposcopy/train/Type_1/1370.jpg ['714', '633', '950', '1630']/data/colposcopy/colposcopy/train/Type_1/1437.jpg ['778', '989', '672', '883']
# ['966', '673', '1088', '2133']
# /data/colposcopy/colposcopy/train/Type_1/191.jpg ['996', '422', '2076', '2670']/data/colposcopy/colposcopy/train/Type_1/254.jpg ['1106', '1548', '578', '680']
#
#
# /data/colposcopy/colposcopy/train/Type_1/338.jpg ['384', '1477', '1226', '1071']/data/colposcopy/colposcopy/train/Type_1/401.jpg ['834', '1363', '1202', '1504']
# /data/colposcopy/colposcopy/train/Type_1/471.jpg ['1226', '723', '352', '477']
#
# /data/colposcopy/colposcopy/train/Type_1/539.jpg ['308', '1288', '818', '625']
# /data/colposcopy/colposcopy/train/Type_1/582.jpg ['1520', '674', '1428', '1431']
# /data/colposcopy/colposcopy/train/Type_1/653.jpg ['682', '2955', '1008', '883']/data/colposcopy/colposcopy/train/Type_1/713.jpg ['1214', '895', '848', '1067']
# /data/colposcopy/colposcopy/train/Type_1/783.jpg ['964', '1254', '906', '971']
#
# /data/colposcopy/colposcopy/train/Type_1/842.jpg ['798', '132', '2100', '3468']
# /data/colposcopy/colposcopy/train/Type_1/908.jpg ['692', '1174', '722', '952']
# /data/colposcopy/colposcopy/train/Type_1/991.jpg ['938', '562', '762', '952']/data/colposcopy/colposcopy/train/Type_2/1017.jpg ['448', '1829', '1386', '1356']
# /data/colposcopy/colposcopy/train/Type_2/1044.jpg ['1342', '806', '1042', '869']
#
# /data/colposcopy/colposcopy/train/Type_2/1067.jpg ['340', '1564', '2006', '689']
# /data/colposcopy/colposcopy/train/Type_2/1089.jpg ['414', '1278', '1342', '1130']
# /data/colposcopy/colposcopy/train/Type_2/1114.jpg ['742', '1254', '676', '687']/data/colposcopy/colposcopy/train/Type_2/1132.jpg
# ['608', '1110', '1400', '1024']
# /data/colposcopy/colposcopy/train/Type_2/1151.jpg ['710', '770', '1574', '1626']
# /data/colposcopy/colposcopy/train/Type_2/1173.jpg ['912', '1449', '500', '516']
# /data/colposcopy/colposcopy/train/Type_2/1192.jpg /data/colposcopy/colposcopy/train/Type_2/1211.jpg ['490', '834', '620', '606']['502', '732', '980', '705']
#
# /data/colposcopy/colposcopy/train/Type_2/1228.jpg ['1234', '2083', '760', '903']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-4c916aa72abd> in <module>()
#      29 print ('Parent process %s.' % os.getpid())
#      30 start_time = time.time()
# ---> 31 a = pool.map(preprocess_cervical_1, img_paths)
#      32 pool.close()
#      33 pool.join()
#
# /root/anaconda2/lib/python2.7/multiprocessing/pool.pyc in map(self, func, iterable, chunksize)
#     251         '''
#     252         assert self._state == RUN
# --> 253         return self.map_async(func, iterable, chunksize).get()
#     254
#     255     def imap(self, func, iterable, chunksize=1):
#
# /root/anaconda2/lib/python2.7/multiprocessing/pool.pyc in get(self, timeout)
#     570             return self._value
#     571         else:
# --> 572             raise self._value
#     573
#     574     def _set(self, i, obj):
#
# TypeError: expected string or Unicode object, numpy.ndarray found
# /data/colposcopy/colposcopy/train/Type_2/1250.jpg/data/colposcopy/colposcopy/train/Type_2/1269.jpg ['776', '602', '2238', '2748']
#  ['592', '891', '740', '1126']
# /data/colposcopy/colposcopy/train/Type_2/1297.jpg ['786', '1618', '1322', '1790']
# /data/colposcopy/colposcopy/train/Type_2/1315.jpg/data/colposcopy/colposcopy/train/Type_2/1331.jpg ['1016', '738', '926', '1517']
#  ['1124', '741', '546', '606']
# /data/colposcopy/colposcopy/train/Type_2/1354.jpg ['200', '1397', '1438', '1341']
# /data/colposcopy/colposcopy/train/Type_2/1371.jpg ['782', '1090', '1348', '1294']
# /data/colposcopy/colposcopy/train/Type_2/1392.jpg ['948', '1381', '610', '597']
# /data/colposcopy/colposcopy/train/Type_2/1419.jpg ['1278', '1532', '630', '844']
# /data/colposcopy/colposcopy/train/Type_2/1444.jpg ['530', '687', '1018', '897']
# /data/colposcopy/colposcopy/train/Type_2/1466.jpg ['1528', '1368', '366', '828']
# /data/colposcopy/colposcopy/train/Type_2/156.jpg ['726', '1692', '1484', '1228']
# /data/colposcopy/colposcopy/train/Type_2/182.jpg ['1154', '1024', '966', '1751']
# /data/colposcopy/colposcopy/train/Type_2/204.jpg ['718', '828', '1106', '1114']
# /data/colposcopy/colposcopy/train/Type_2/231.jpg ['878', '1012', '1114', '1329']
# /data/colposcopy/colposcopy/train/Type_2/251.jpg ['702', '596', '886', '1573']
# /data/colposcopy/colposcopy/train/Type_2/282.jpg ['846', '590', '1066', '1286']
# /data/colposcopy/colposcopy/train/Type_2/303.jpg/data/colposcopy/colposcopy/train/Type_2/330.jpg ['1182', '1161', '472', '375']
#  ['1302', '935', '1050', '1149']
# /data/colposcopy/colposcopy/train/Type_2/358.jpg ['928', '958', '682', '640']
# /data/colposcopy/colposcopy/train/Type_2/374.jpg ['830', '1485', '1050', '973']
# /data/colposcopy/colposcopy/train/Type_2/397.jpg ['810', '840', '686', '754']
# /data/colposcopy/colposcopy/train/Type_2/414.jpg ['914', '609', '1202', '1290']
# /data/colposcopy/colposcopy/train/Type_2/440.jpg/data/colposcopy/colposcopy/train/Type_2/457.jpg/data/colposcopy/colposcopy/train/Type_2/485.jpg ['558', '1938', '944', '1079']
#  ['406', '1211', '1110', '1130']
# /data/colposcopy/colposcopy/train/Type_2/506.jpg ['840', '1813', '1192', '1439']
#  ['296', '1172', '1462', '1126']
# /data/colposcopy/colposcopy/train/Type_2/528.jpg/data/colposcopy/colposcopy/train/Type_2/545.jpg ['380', '922', '1846', '2115'] ['416', '1211', '2336', '1732']
# /data/colposcopy/colposcopy/train/Type_2/566.jpg ['712', '757', '892', '946']
#
# /data/colposcopy/colposcopy/train/Type_2/592.jpg ['930', '594', '1682', '2134']
# /data/colposcopy/colposcopy/train/Type_2/612.jpg ['992', '1536', '894', '1192']
# /data/colposcopy/colposcopy/train/Type_2/640.jpg ['874', '1630', '1296', '1802']
# /data/colposcopy/colposcopy/train/Type_2/66.jpg ['1052', '1133', '1494', '1368']
# /data/colposcopy/colposcopy/train/Type_2/684.jpg ['1566', '312', '1274', '2291']
# /data/colposcopy/colposcopy/train/Type_2/705.jpg ['812', '1020', '1172', '1098']
# /data/colposcopy/colposcopy/train/Type_2/726.jpg/data/colposcopy/colposcopy/train/Type_2/756.jpg ['808', '648', '1642', '1318']
#  ['706', '1230', '598', '751']
# /data/colposcopy/colposcopy/train/Type_2/785.jpg ['746', '1008', '746', '919']
# /data/colposcopy/colposcopy/train/Type_2/804.jpg/data/colposcopy/colposcopy/train/Type_2/834.jpg ['1170', '289', '1664', '1188']
#  ['708', '1286', '1658', '1856']
# /data/colposcopy/colposcopy/train/Type_2/856.jpg ['874', '1157', '732', '785']
# /data/colposcopy/colposcopy/train/Type_2/874.jpg ['486', '1606', '1520', '1083']
# /data/colposcopy/colposcopy/train/Type_2/904.jpg /data/colposcopy/colposcopy/train/Type_2/93.jpg ['1716', '1145', '1256', '1298']
# ['726', '948', '922', '977']
# /data/colposcopy/colposcopy/train/Type_2/948.jpg ['342', '1207', '2126', '1517']
# /data/colposcopy/colposcopy/train/Type_2/969.jpg ['984', '1098', '828', '962']
# /data/colposcopy/colposcopy/train/Type_2/989.jpg ['638', '865', '854', '1029']
# /data/colposcopy/colposcopy/train/Type_3/1015.jpg ['612', '1177', '836', '708']
# /data/colposcopy/colposcopy/train/Type_3/106.jpg ['730', '1007', '622', '668']
# /data/colposcopy/colposcopy/train/Type_3/1094.jpg ['700', '1610', '1120', '1450']
# /data/colposcopy/colposcopy/train/Type_3/1128.jpg ['962', '1217', '514', '467']
# /data/colposcopy/colposcopy/train/Type_3/1166.jpg ['1138', '1060', '490', '525']
# /data/colposcopy/colposcopy/train/Type_3/1232.jpg/data/colposcopy/colposcopy/train/Type_3/1275.jpg ['1650', '1231', '480', '977'] ['1378', '1055', '970', '1263']
#
# /data/colposcopy/colposcopy/train/Type_3/132.jpg ['1224', '1366', '372', '300']
# /data/colposcopy/colposcopy/train/Type_3/1366.jpg ['942', '1737', '620', '479']
# /data/colposcopy/colposcopy/train/Type_3/1403.jpg ['746', '1721', '542', '643']
# /data/colposcopy/colposcopy/train/Type_3/1442.jpg ['628', '1712', '640', '981']
# /data/colposcopy/colposcopy/train/Type_3/1477.jpg ['920', '599', '536', '869']
# /data/colposcopy/colposcopy/train/Type_3/179.jpg ['1430', '1626', '662', '793']
# /data/colposcopy/colposcopy/train/Type_3/211.jpg ['860', '1109', '386', '733']
# /data/colposcopy/colposcopy/train/Type_3/249.jpg/data/colposcopy/colposcopy/train/Type_3/277.jpg ['938', '1041', '706', '575']
#  /data/colposcopy/colposcopy/train/Type_3/309.jpg ['416', '656', '1086', '1236']
# ['924', '1035', '1266', '915']
# /data/colposcopy/colposcopy/train/Type_3/344.jpg ['778', '374', '474', '778']
# /data/colposcopy/colposcopy/train/Type_3/390.jpg/data/colposcopy/colposcopy/train/Type_3/430.jpg ['938', '828', '1150', '1032']
# /data/colposcopy/colposcopy/train/Type_3/477.jpg ['638', '1105', '744', '976']
#  ['742', '695', '456', '714']
# /data/colposcopy/colposcopy/train/Type_3/510.jpg ['758', '825', '818', '603']
# /data/colposcopy/colposcopy/train/Type_3/571.jpg ['692', '809', '624', '810']
# /data/colposcopy/colposcopy/train/Type_3/606.jpg ['1000', '1000', '464', '556']
# /data/colposcopy/colposcopy/train/Type_3/636.jpg ['572', '1817', '606', '933']
# /data/colposcopy/colposcopy/train/Type_3/682.jpg ['1042', '868', '878', '998']
# /data/colposcopy/colposcopy/train/Type_3/721.jpg ['1242', '1560', '640', '492']/data/colposcopy/colposcopy/train/Type_3/750.jpg
# ['1158', '899', '598', '1133']
# /data/colposcopy/colposcopy/train/Type_3/782.jpg ['786', '1579', '962', '621']
# /data/colposcopy/colposcopy/train/Type_3/82.jpg ['912', '1348', '1488', '2240']
# /data/colposcopy/colposcopy/train/Type_3/853.jpg ['534', '1279', '1492', '1051']
# /data/colposcopy/colposcopy/train/Type_3/892.jpg ['994', '1622', '560', '656']
# /data/colposcopy/colposcopy/train/Type_3/924.jpg ['1258', '528', '456', '726']
# /data/colposcopy/colposcopy/train/Type_3/954.jpg ['1350', '1632', '466', '630']
